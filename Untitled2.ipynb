# %% [markdown]
# <a href="https://colab.research.google.com/github/nikitha-kote/demo_nikitha/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fe577aeb-e9e3-4369-b90a-e5c92b90bf44" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe577aeb-e9e3-4369-b90a-e5c92b90bf44">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as numpyInstace
import pandas as pandaInstace
import matplotlib.pyplot as matplotlibInstace
import seaborn as seabornInstace

# %%
weatherData=pandaInstace.read_csv('weather.csv')
weatherData.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
weatherData.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
seabornInstace.scatterplot(x='MinTemp' , y='MaxTemp' ,data=weatherData)
# Out:
# <Axes: xlabel='MinTemp', ylabel='MaxTemp'>

# %%
seabornInstace.jointplot(x='MinTemp' , y='MaxTemp' ,data=weatherData)

# %%
seabornInstace.lmplot(x='MinTemp' , y='MaxTemp' ,data=weatherData)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,10))
plt.tight_layout()
sns.heatmap(weatherData.select_dtypes(include=['number']).corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4264989064.py in <cell line: 0>()
#       3 plt.figure(figsize=(10,10))
#       4 plt.tight_layout()
# ----> 5 sns.heatmap(weatherData.select_dtypes(include=['number']).corr(),annot=True)
#
# NameError: name 'weatherData' is not defined

# %%
plt.figure(figsize=(12,10))
plt.tight_layout()
sns.heatmap(weatherData.select_dtypes(include=['number']).corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2001080753.py in <cell line: 0>()
#       1 plt.figure(figsize=(12,10))
#       2 plt.tight_layout()
# ----> 3 sns.heatmap(weatherData.select_dtypes(include=['number']).corr(),annot=True)
#
# NameError: name 'weatherData' is not defined
